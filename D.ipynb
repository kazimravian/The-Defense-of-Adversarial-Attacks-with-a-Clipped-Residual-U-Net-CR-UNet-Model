# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist, fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model
import tensorflow.keras.backend as k
from tensorflow.keras.utils import get_custom_objects

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#tf.compat.v1.disable_eager_execution()

# %%
# download the dataset
(x_train, y_train), (x_val, y_val) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# image classes or categories
class_names = ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']

# %%
print("Number of Training Samples: ", len(x_train))
print("Number of Validation Samples: ", len(x_val))
# Out:
# Number of Training Samples:  60000
# Number of Validation Samples:  10000

# %%
# shape of images
print("Shape of Training images: ", x_train.shape)
print("Shape of Validation images: ", x_val.shape)
# Out:
# Shape of Training images:  (60000, 28, 28)
# Shape of Validation images:  (10000, 28, 28)

# %%
# reshape for training and testing
x_train = x_train.reshape(60000, 28, 28, 1)
x_val = x_val.reshape(10000, 28, 28, 1)

# %%
# change data type
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')

# %%
# normalize data into range 1-0
x_train /= 255.0
x_val /= 255.0

# %%
print("Training shape: ", x_train.shape)
print("Validation shape: ", x_val.shape)
# Out:
# Training shape:  (60000, 28, 28, 1)
# Validation shape:  (10000, 28, 28, 1)

# %%
# show some training images
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(x_train[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_train[idx]])

# %%
model = Sequential()

model.add(Conv2D(filters = 128, kernel_size = (3, 3), strides = 1, input_shape = (28, 28, 1)))
model.add(Activation('relu'))


model.add(Conv2D(filters = 64, kernel_size = (3, 3), strides = 2))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(units = 200))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 200))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 10, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 128)       1280
#
#  activation (Activation)     (None, 26, 26, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)        73792
#
#  activation_1 (Activation)   (None, 12, 12, 64)        0
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 200)               1843400
#
#  activation_2 (Activation)   (None, 200)               0
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_1 (Dense)             (None, 200)               40200
#
#  activation_3 (Activation)   (None, 200)               0
#
#  dropout_2 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 10)                2010
#
# =================================================================
# Total params: 1,960,682
# Trainable params: 1,960,682
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#model.save('./drive/My Drive/PhD_Thesis/models/D/D.h5')

# %%
model = load_model('./drive/My Drive/PhD_Thesis/models/D/D.h5')

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val, y_val)
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 313/313 [==============================] - 30s 3ms/step - loss: 0.0299 - accuracy: 0.9912
#
# Model Accuracy on test images:  0.9912
# Model Loss on test images:  0.0299

# %%
# predict some testing images
predictions = model.predict(x_val)

# show test images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(x_val[idx].reshape(28, 28), cmap = 'gray')
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(x_val[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[np.argmax(predictions[idx])], color =  color)

# %% [markdown]
# **Gradient Based Attack**

# %% [markdown]
# ## 1. Fast Gradient Sign Attack and Reconstruction of Adversarial Example

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0290 - accuracy: 0.9920
#
# Model Accuracy on test images:  0.992
# Model Loss on test images:  0.029

# %%
import pickle
out = open('./drive/My Drive/PhD_Thesis/adv_examples/D/fgsm.pickle', 'rb')
adv_fgsm = pickle.load(out)

# %%
adv_pred = model.predict(adv_fgsm)

# %%
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_fgsm[idx].reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[int(np.argmax(adv_pred[idx]))], color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_fgsm[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 3.7204 - accuracy: 0.3080
#
# Model Accuracy on test images:  0.308
# Model Loss on test images:  3.7204

# %%
# load denoising model to remove FGSM putrbation
d_model = runet_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/runet_models/D/runet_fgsm.h5')

# %%
# Restore adversarial images created due to FGSM attack 
deniose_fgsm = d_model.predict(adv_fgsm)

# %%
# predict some restored images
predictions = model.predict(deniose_fgsm)

# %%
# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
    
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(deniose_fgsm[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[np.argmax(predictions[idx])], color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(deniose_fgsm[:1000], y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9920
#
# Model Accuracy on restored images:  0.992
# Model Loss on test images:  0.0294

# %%
print('Sucess of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess of Defence Model:  1.0

# %% [markdown]
# # 2. Basic Iterative Method (Attack) and Reconstruction of Adversarial Examples

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 0.9920
#
# Model Accuracy on test images:  0.992
# Model Loss on test images:  0.029

# %%
import pickle
out = open('./drive/My Drive/PhD_Thesis/adv_examples/D/bim.pickle', 'rb')
adv_bim = pickle.load(out)

# %%
adv_pred = model.predict(adv_bim)

# %%
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_bim[idx].reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[int(np.argmax(adv_pred[idx]))], color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_bim[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 18.2393 - accuracy: 0.0540
#
# Model Accuracy on test images:  0.054
# Model Loss on test images:  18.2393

# %%
# load denoising model to remove BIM putrbation
d_model = runet_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/runet_models/D/runet_bim.h5')

# %%
# Restore adversarial images created due to BIM attack 
deniose_bim = d_model.predict(adv_bim)

# %%
# predict some restored images
predictions = model.predict(deniose_bim)

# %%
# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
    
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(deniose_bim[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[np.argmax(predictions[idx])], color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(deniose_bim[:1000], y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 0.9920
#
# Model Accuracy on restored images:  0.992
# Model Loss on test images:  0.0284

# %%
print('Sucess of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess of Defence Model:  1.0

# %% [markdown]
# #3. Projected Gradient Descent Attack and Reconstruction of Adverasarial Examples

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val, y_val)
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0299 - accuracy: 0.9912
#
# Model Accuracy on test images:  0.9912
# Model Loss on test images:  0.0299

# %%
import pickle
out = open('./drive/My Drive/PhD_Thesis/adv_examples/D/pgd.pickle', 'rb')
adv_pgd = pickle.load(out)

# %%
adv_pred = model.predict(adv_pgd)

# %%
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_pgd[idx].reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[int(np.argmax(adv_pred[idx]))], color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_pgd[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 6.6232 - accuracy: 0.1830
#
# Model Accuracy on test images:  0.183
# Model Loss on test images:  6.6232

# %%
# load denoising model to remove PGD putrbation
d_model = runet_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/runet_models/D/runet_pgd.h5')

# %%
# Restore adversarial images created due to PGD attack 
deniose_pgd = d_model.predict(adv_pgd)

# %%
# predict some restored images
predictions = model.predict(deniose_pgd)

# %%
# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
    
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(deniose_pgd[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[np.argmax(predictions[idx])], color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(deniose_pgd[:1000], y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 0.9910
#
# Model Accuracy on restored images:  0.991
# Model Loss on test images:  0.0294

# %%
print('Sucess of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess of Defence Model:  0.9998

# %% [markdown]
# #4. Deep Fool Attack

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val, y_val)
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0299 - accuracy: 0.9912
#
# Model Accuracy on test images:  0.9912
# Model Loss on test images:  0.0299

# %%
import pickle
out = open('./drive/My Drive/PhD_Thesis/adv_examples/D/dfa.pickle', 'rb')
adv_dfa = pickle.load(out)

# %%
adv_pred = model.predict(adv_dfa)

# %%
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(adv_dfa[idx].reshape(28, 28), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[int(np.argmax(adv_pred[idx]))], color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_dfa[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 1.6334 - accuracy: 0.6350
#
# Model Accuracy on test images:  0.635
# Model Loss on test images:  1.6334

# %%
# load denoising model to remove DFA putrbation
d_model = runet_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/runet_models/D/runet_dfa.h5')

# %%
# Restore adversarial images created due to DFA attack 
deniose_dfa = d_model.predict(adv_dfa)

# %%
# predict some restored images
predictions = model.predict(deniose_dfa)

# %%
# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
    
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(deniose_dfa[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[np.argmax(predictions[idx])], color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(deniose_dfa[:1000], y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9920
#
# Model Accuracy on restored images:  0.992
# Model Loss on test images:  0.031

# %%
print('Sucess of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess of Defence Model:  1.0008

# %% [markdown]
# # 5. Carlini and Wanger Attack

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9920
#
# Model Accuracy on test images:  0.992
# Model Loss on test images:  0.029

# %%
import pickle
out = open('./drive/My Drive/PhD_Thesis/adv_examples/D/cwa.pickle', 'rb')
adv_cwa = pickle.load(out)

# %%
adv_pred = model.predict(adv_cwa)

# %%
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_cwa[idx].reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[int(np.argmax(adv_pred[idx]))], color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_cwa, y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2417 - accuracy: 0.9320
#
# Model Accuracy on test images:  0.932
# Model Loss on test images:  0.2417

# %%
# load denoising model to remove DFA putrbation
d_model = runet_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/runet_models/D/runet_cwa.h5')

# %%
# Restore adversarial images created due to DFA attack 
deniose_cwa = d_model.predict(adv_cwa)

# %%
# predict some restored images
predictions = model.predict(deniose_cwa)

# %%
# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
    
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(deniose_cwa[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[np.argmax(predictions[idx])], color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(deniose_cwa, y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9910
#
# Model Accuracy on restored images:  0.991
# Model Loss on test images:  0.0313

# %%
print('Sucess of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess of Defence Model:  0.999

# %% [markdown]
# # 6. Spatial attack and Reconstruction of Adverasarial Examples

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9920
#
# Model Accuracy on test images:  0.992
# Model Loss on test images:  0.029

# %%
import pickle
out = open('./drive/My Drive/PhD_Thesis/adv_examples/D/spa.pickle', 'rb')
adv_spa = pickle.load(out)

# %%
adv_pred = model.predict(adv_spa)

# %%
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_spa[idx].reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[int(np.argmax(adv_pred[idx]))], color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_spa[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 5.3250 - accuracy: 0.0000e+00
#
# Model Accuracy on test images:  0.0
# Model Loss on test images:  5.325

# %%
# load denoising model to remove SPA putrbation
d_model = runet_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/runet_models/D/runet_spa.h5')

# %%
# Restore adversarial images created due to SP attack 
deniose_spa = d_model.predict(adv_spa)

# %%
# predict some restored images
predictions = model.predict(deniose_spa)

# %%
# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
    
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(deniose_spa[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[np.argmax(predictions[idx])], color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(deniose_spa[:1000], y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9930
#
# Model Accuracy on restored images:  0.993
# Model Loss on test images:  0.0291

# %%
print('Sucess of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess of Defence Model:  1.001

# %% [markdown]
# # Some examples of Restored examples

# %%
adv_examples = np.concatenate([fgsm_imgs[:2], bim_imgs[2:4], pgd_imgs[4:6], dfa_imgs[6:8], cwa_imgs[8:10], spa_imgs[10:12]])
adv_examples.shape
# Out:
# (12, 28, 28, 1)

# %%
adv_pert = np.concatenate([fgsm_p[:2], bim_p[2:4], pgd_p[4:6], dfa_p[6:8], cwa_p[8:10], spa_p[10:12]])
adv_pert = 3 * adv_pert

# %%
restored_examples = np.concatenate([denise_fgsm[:2], denise_bim[2:4], denise_pgd[4:6], denise_dfa[6:8], denise_cwa[8:10], denise_spa[10:12]])
restored_examples.shape
# Out:
# (12, 28, 28, 1)

# %%
imgs = np.concatenate([x_val[:12].reshape(12, 28, 28), adv_pert.reshape(12, 28, 28) ,adv_examples.reshape(12, 28, 28), restored_examples[:12].reshape(12, 28, 28)])
imgs = imgs.reshape((4, 12, 28, 28))
imgs = np.clip(imgs, 0, 1)
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure(figsize = (16, 5))
plt.axis('off')
#plt.title('Input: 1st 2 rows, Decoded: last 2 rows')
plt.imshow(imgs, cmap = 'gray')

# %%
# Out:
# ()

# %%
# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(48):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
    
  plt.imshow(imgs[idx], cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-e2de9cab5ffa> in <module>()
#       4   ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
#       5
# ----> 6   plt.imshow(imgs[idx].reshape(112, 336), cmap = 'gray')
#
# ValueError: cannot reshape array of size 336 into shape (112,336)
